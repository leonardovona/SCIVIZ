# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardovona/SCIVIZ/blob/main/Data%20Preparation/Water%20abstraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./water-abstraction-by-economic-sector-1.csv', sep=',')

# %%
df
# Out:
#      Country:text Economic activity:text  Year:text  Value:number
# 0        Bulgaria            Agriculture       2000        1184.6
# 1        Bulgaria            Agriculture       2001         865.2
# 2        Bulgaria            Agriculture       2002         743.0
# 3        Bulgaria            Agriculture       2003        1096.7
# 4        Bulgaria            Agriculture       2004         900.5
# ...           ...                    ...        ...           ...
# 4477  Switzerland    Public water supply       2015         933.0
# 4478  Switzerland    Public water supply       2016         923.0
# 4479  Switzerland    Public water supply       2017         931.0
# 4480  Switzerland    Public water supply       2018         953.0
# 4481  Switzerland    Public water supply       2019         950.6
#
# [4482 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4482 entries, 0 to 4481
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country:text            4482 non-null   object
#  1   Economic activity:text  4482 non-null   object
#  2   Year:text               4482 non-null   int64
#  3   Value:number            4481 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 140.2+ KB

# %%
df = df.dropna(how="all")

# %%
df.rename({'Country:text': 'country', 'Economic activity:text': 'economic_activity', 'Year:text': 'year', 'Value:number': 'value'}, axis=1, inplace=True)

# %%
df
# Out:
#           country    economic_activity  year   value
# 0        Bulgaria          Agriculture  2000  1184.6
# 1        Bulgaria          Agriculture  2001   865.2
# 2        Bulgaria          Agriculture  2002   743.0
# 3        Bulgaria          Agriculture  2003  1096.7
# 4        Bulgaria          Agriculture  2004   900.5
# ...           ...                  ...   ...     ...
# 4477  Switzerland  Public water supply  2015   933.0
# 4478  Switzerland  Public water supply  2016   923.0
# 4479  Switzerland  Public water supply  2017   931.0
# 4480  Switzerland  Public water supply  2018   953.0
# 4481  Switzerland  Public water supply  2019   950.6
#
# [4482 rows x 4 columns]

# %%
non_EU_countries = ['Albania', 'Bosnia and Herzegovina', 'Iceland', 'Kosovo*', 'Montenegro', 'North Macedonia', 'Norway', 'Serbia', 'Switzerland', 'Türkiye']

df = df[~df.country.isin(non_EU_countries)]

# %%
countries = sorted(df['country'].unique())
IDs = ["AT", "BE", "BG", "HR", "CY", "CZ", "DK", "EE", "FI", "FR", "DE", "EL",
       "HU", "IE", "IT", "LV", "LT", "LU", "MT", "NL", "PL", "PT", "RO", "SK",
       "SI", "ES", "SE"]

countries_to_IDs = dict(zip(countries, IDs))
df['country'] = df['country'].map(countries_to_IDs)
df['country']
# Out:
# <ipython-input-88-8ebea8e92b83>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['country'] = df['country'].map(countries_to_IDs)
# 0       BG
# 1       BG
# 2       BG
# 3       BG
# 4       BG
#         ..
# 4457    NL
# 4458    NL
# 4459    NL
# 4460    NL
# 4461    NL
# Name: country, Length: 3449, dtype: object

# %%
# df[(df['reportingYear'] == 2007) & (df['pollutant'] == 'Trichloromethane')]['emissions'].sum()

# %%
# import itertools
# pollutants = df['pollutant'].unique().tolist()

# for (year, pollutant) in itertools.product(range(2007,2020), pollutants):
#   df[(df['reportingYear'] == year) & (df['pollutant'] == pollutant)]['emissions'].sum()

# %%
# for year in range(2007, 2020):
#   df[df['reportingYear'] == year].sum()

# %%
df[df['year'] == 2007]
# Out:
#      country      economic_activity  year   value
# 7         BG            Agriculture  2007  1015.3
# 40        BG    Electricity cooling  2007  3492.8
# 60        BG          Manufacturing  2007   228.0
# 80        BG  Manufacturing cooling  2007   114.5
# 100       BG   Mining and quarrying  2007    27.8
# ...      ...                    ...   ...     ...
# 4369      NL    Electricity cooling  2007  6068.4
# 4389      NL          Manufacturing  2007  2952.1
# 4409      NL  Manufacturing cooling  2007  2856.6
# 4429      NL   Mining and quarrying  2007     0.9
# 4449      NL    Public water supply  2007  1248.4
#
# [172 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3449 entries, 0 to 4461
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            3449 non-null   object
#  1   economic_activity  3449 non-null   object
#  2   year               3449 non-null   int64
#  3   value              3448 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 134.7+ KB

# %%
df.economic_activity.unique()
# Out:
# array(['Agriculture', 'Construction', 'Electricity cooling',
#        'Manufacturing', 'Manufacturing cooling', 'Mining and quarrying',
#        'Public water supply'], dtype=object)

# %%
df
# Out:
#      country    economic_activity  year   value
# 0         BG          Agriculture  2000  1184.6
# 1         BG          Agriculture  2001   865.2
# 2         BG          Agriculture  2002   743.0
# 3         BG          Agriculture  2003  1096.7
# 4         BG          Agriculture  2004   900.5
# ...      ...                  ...   ...     ...
# 4457      NL  Public water supply  2015  1237.2
# 4458      NL  Public water supply  2016  1260.3
# 4459      NL  Public water supply  2017  1199.4
# 4460      NL  Public water supply  2018  1312.2
# 4461      NL  Public water supply  2019  1302.2
#
# [3449 rows x 4 columns]

# %%
df = df.pivot_table(index=['year', 'country'], columns='economic_activity', values='value')

# %%
df
# Out:
# economic_activity  Agriculture  Construction  Electricity cooling  \
# year country
# 2000 AT                  100.0           NaN               1629.4
#      BE                   35.6         237.8               5097.8
#      BG                 1184.6           2.2               3227.9
#      CY                  144.7           NaN                  0.0
#      CZ                   14.5           NaN                513.8
# ...                        ...           ...                  ...
# 2019 PT                 3820.2           0.0                632.9
#      RO                 1351.9           0.0               1842.3
#      SE                   53.4           NaN                 72.7
#      SI                    3.4           NaN                727.1
#      SK                   28.7           0.0                 54.6
#
# economic_activity  Manufacturing  Manufacturing cooling  Mining and quarrying  \
# year country
# 2000 AT                   1259.2                    0.0                   0.0
#      BE                   1383.9                  997.3                  33.1
#      BG                    400.0                  170.9                  44.5
#      CY                      9.6                    0.0                   0.0
#      CZ                    370.3                    0.0                   0.0
# ...                          ...                    ...                   ...
# 2019 PT                      0.0                    0.0                   0.0
#      RO                      0.0                    0.0                   0.0
#      SE                      0.0                    0.0                   0.0
#      SI                     41.7                    0.0                   1.0
#      SK                    164.2                   32.4                   0.6
#
# economic_activity  Public water supply
# year country
# 2000 AT                          587.7
#      BE                          745.0
#      BG                         1178.0
#      CY                           46.3
#      CZ                          807.9
# ...                                ...
# 2019 PT                          787.4
#      RO                         1075.7
#      SE                          787.2
#      SI                          170.0
#      SK                          292.4
#
# [540 rows x 7 columns]

# %%
# import itertools

# index_pairs = df.index.to_list()

# for (year, ID) in itertools.product(range(2007,2020), IDs):
#     if not((year, ID) in index_pairs):
#       print((year, ID))
#       df.loc[(year, ID), :] = (np.NaN, np.NaN, np.NaN, np.NaN)

# %%
newidx = [df.index.levels[0],
          df.index.levels[1].append(pd.Index(data=['EU']))]

df = df.reindex(pd.MultiIndex.from_product(newidx, names=df.index.names))

# %%
for year in range(2007, 2020):
  df.loc[(year, "EU"), :] = df.loc[year].sum()

# %%
df = df.sort_index()

# %%
df.replace(np.NaN, 0, inplace=True)

# %%
df.loc[2007]
# Out:
# economic_activity  Agriculture  Construction  Electricity cooling  \
# country
# AT                        54.5           0.0               1701.3
# BE                        37.0         131.8               3992.2
# BG                      1015.3           0.0               3492.8
# CY                       143.0           0.0                  0.0
# CZ                        29.8           0.5                607.1
# DE                       131.7         204.3              19058.2
# DK                       117.5           0.0                  1.8
# EE                         7.6           0.0               1630.2
# EL                      8458.0           0.0                100.4
# ES                     23180.0           0.0               5850.0
# EU                     56207.6         574.2              87358.4
# FI                        39.8           0.0                372.0
# FR                      3932.8           0.0              18509.8
# HR                        30.0           0.0                110.0
# HU                       169.7         224.2               4176.1
# IE                         0.0           0.0                456.6
# IT                     12890.0           0.0               6019.4
# LT                        81.8           0.2               1979.4
# LU                         0.0           0.0                  0.0
# LV                        50.7           0.9                  2.2
# MT                        23.2           0.0                 24.4
# NL                        71.9           0.0               6068.4
# PL                      1122.0          12.3               7213.1
# PT                      3388.1           0.0               1499.4
# RO                      1099.0           0.0               3496.0
# SE                       107.0           0.0                116.0
# SI                         4.7           0.0                706.3
# SK                        22.5           0.0                175.3
#
# economic_activity  Manufacturing  Manufacturing cooling  Mining and quarrying  \
# country
# AT                        1557.5                    0.0                   0.0
# BE                        1257.6                 1021.2                  37.5
# BG                         228.0                  114.5                  27.8
# CY                           5.9                    0.0                   0.0
# CZ                         303.8                   75.5                  42.1
# DE                        4896.8                    0.0                2294.2
# DK                          41.8                    0.0                   0.0
# EE                          39.5                    0.0                 196.6
# EL                         233.7                    0.0                  67.0
# ES                         645.0                  108.3                   0.0
# EU                       32256.5                 5068.0                2888.6
# FI                        2599.9                    0.0                   0.0
# FR                        2165.3                    0.0                   0.0
# HR                          64.7                   41.0                   3.5
# HU                          81.0                    0.0                  53.6
# IE                          33.7                    0.0                  51.0
# IT                       11661.0                    0.0                   0.0
# LT                          35.2                    0.0                   1.4
# LU                           2.7                    0.0                   0.0
# LV                          27.7                    0.0                   5.5
# MT                           1.0                    0.0                   0.0
# NL                        2952.1                 2856.6                   0.9
# PL                         491.7                  265.9                  81.8
# PT                         396.0                    0.0                   0.0
# RO                         775.0                    0.0                   9.0
# SE                        1398.0                  585.0                  15.0
# SI                          54.9                    0.0                   1.7
# SK                         307.0                    0.0                   0.0
#
# economic_activity  Public water supply
# country
# AT                               548.0
# BE                               728.3
# BG                              1026.4
# CY                                65.6
# CZ                               701.6
# DE                              5127.6
# DK                               405.7
# EE                                47.8
# EL                               846.3
# ES                              5790.0
# EU                             36052.5
# FI                               409.6
# FR                              5683.0
# HR                               491.5
# HU                               666.6
# IE                               609.0
# IT                              5417.7
# LT                               132.5
# LU                                36.5
# LV                               116.6
# MT                                14.0
# NL                              1248.4
# PL                              2085.6
# PT                               976.3
# RO                              1493.0
# SE                               898.0
# SI                               167.4
# SK                               319.5

# %%
df = df.reset_index(level=[0,1])

# %%
for year in range(2007,2020):
  df.to_csv(path_or_buf="./water_abstraction.csv")
